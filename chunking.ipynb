# %%
from vectordb import (
    # Chunking
    chunk_markdown,
    chunk_text,
    ChunkingConfig,
    ChunkingStrategy,
    
    # Embeddings
    embed_markdown,
    EmbeddingConfig,
    create_embed_function,
    
    # Vector Store
    build_vector_store,
    query_vector_store,
    VectorStoreConfig,
    
    # Utilities
    get_chunk_statistics,
    get_embedding_statistics,
    get_store_statistics
)

# %%
chunks = chunk_markdown("data/pdfs/clean.md")
print(f"Created {len(chunks)} chunks")
# Out:
# Created 750 chunks

# %%
chunks = chunk_markdown("data/pdfs/clean.md")
print(f"Created {len(chunks)} chunks")
# Out:
# Created 750 chunks

# %%
print(chunks)
# Out:
# [Chunk(content='## Preface\nWeb development has been changing a lot in the last couple of years. JavaScript\nlibraries have matured, browsers have become more powerful, and the HTML5 spec\nis well supported on most systems. Currently, though, the Web mostly focuses on 2D\nto represent information, create games, and build websites. There is also, however, a\ngreat and standardized way to create 3D graphics. This is called WebGL; it provides\nan API to create hardware-accelerated 3D graphics.', source_file='/Users/anedu/Documents/programing/rag_pipeline/data/pdfs/clean.md', chunk_index=0, start_char=0, end_char=473, metadata={'frontmatter': {}, 'file_name': 'clean.md', 'chunk_size': 473, 'strategy': 'recursive'}), Chunk(content="However, the WebGL API isn't very easy to use. It requires you to program in C,\nand you really need to have an in-depth knowledge of how WebGL works\ninternally to work with this API. Luckily though, there are a number of JavaScript\nlibraries available that h
# ...

# %%
embeddings = embed_markdown(chunks)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:127, in create_sentence_transformers_provider(config)
#     126 try:
# --> 127     from sentence_transformers import SentenceTransformer
#     128 except ImportError:
#
# ModuleNotFoundError: No module named 'sentence_transformers'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 embeddings = embed_markdown(chunks)
#
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:302, in embed_markdown(chunks, provider_type, config)
#     275 """
#     276 Main entry point for embedding chunks from markdown files.
#     277
#    (...)    299     embeddings = embed_markdown(chunks, "openai", config)
#     300 """
# ...

# %%
uv add sentence-transformers
# Out:
# /Users/anedu/Documents/programing/rag_pipeline/.venv/bin/python3: No module named uv
# Note: you may need to restart the kernel to use updated packages.

# %%
embeddings = embed_markdown(chunks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 embeddings = embed_markdown(chunks)
#
# NameError: name 'embed_markdown' is not defined

# %%
embeddings = embed_markdown(chunks, "openai")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 embeddings = embed_markdown(chunks, "openai")
#
# NameError: name 'embed_markdown' is not defined

# %%
from vectordb import {embed_markdown}
# Out:
#   Cell In[3], line 1
#     from vectordb import {embed_markdown}
#                          ^
# SyntaxError: invalid syntax

# %%
from vectordb import embed_markdown

# %%
embeddings = embed_markdown(chunks, "openai")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 embeddings = embed_markdown(chunks, "openai")
#
# NameError: name 'chunks' is not defined

# %%
print(chunks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(chunks)
#
# NameError: name 'chunks' is not defined

# %%
chunks = chunk_markdown("data/pdfs/clean.md")
print(f"Created {len(chunks)} chunks")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 chunks = chunk_markdown("data/pdfs/clean.md")
#       2 print(f"Created {len(chunks)} chunks")
#
# NameError: name 'chunk_markdown' is not defined

# %%
from vectordb import (chunk_markdown, embed_markdown)

# %%
chunks = chunk_markdown("data/pdfs/clean.md")
print(f"Created {len(chunks)} chunks")
# Out:
# Created 750 chunks

# %%
embeddings = embed_markdown(chunks, "openai")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 embeddings = embed_markdown(chunks, "openai")
#
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:308, in embed_markdown(chunks, provider_type, config)
#     281 """
#     282 Main entry point for embedding chunks from markdown files.
#     283
#    (...)    305     embeddings = embed_markdown(chunks, "openai", config)
#     306 """
#     307 config = config or EmbeddingConfig()
# --> 308 provider = get_provider(provider_type, config)
#     309 return embed_chunks(chunks, provider, config.batch_size)
#
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:186, in get_provider(provider_type, config)
#     181 if provider_type not in providers:
#     182     raise ValueError(
#     183         f"Unknown provider: {provider_type}. Available: {list(providers.keys())}"
# ...

# %%
embeddings = embed_markdown(chunks, "openai")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 embeddings = embed_markdown(chunks, "openai")
#
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:308, in embed_markdown(chunks, provider_type, config)
#     281 """
#     282 Main entry point for embedding chunks from markdown files.
#     283
#    (...)    305     embeddings = embed_markdown(chunks, "openai", config)
#     306 """
#     307 config = config or EmbeddingConfig()
# --> 308 provider = get_provider(provider_type, config)
#     309 return embed_chunks(chunks, provider, config.batch_size)
#
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:186, in get_provider(provider_type, config)
#     181 if provider_type not in providers:
#     182     raise ValueError(
#     183         f"Unknown provider: {provider_type}. Available: {list(providers.keys())}"
# ...

# %%
from vectordb import (embed_markdown, chunk_markdown)

# %%
chunks = chunk_markdown("data/pdfs/clean.md")
print(f"Created {len(chunks)} chunks")
# Out:
# Created 750 chunks

# %%
embed = embed_markdown(chunks, "openai")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 embed = embed_markdown(chunks, "openai")
#
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:308, in embed_markdown(chunks, provider_type, config)
#     281 """
#     282 Main entry point for embedding chunks from markdown files.
#     283
#    (...)    305     embeddings = embed_markdown(chunks, "openai", config)
#     306 """
#     307 config = config or EmbeddingConfig()
# --> 308 provider = get_provider(provider_type, config)
#     309 return embed_chunks(chunks, provider, config.batch_size)
#
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:186, in get_provider(provider_type, config)
#     181 if provider_type not in providers:
#     182     raise ValueError(
#     183         f"Unknown provider: {provider_type}. Available: {list(providers.keys())}"
# ...

# %%
embed = embed_markdown(chunks, "openai")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 embed = embed_markdown(chunks, "openai")
#
# NameError: name 'embed_markdown' is not defined

# %%
from vectordb import (embed_markdown, chunk_markdown)

# %%
chunks = chunk_markdown("data/pdfs/clean.md")
print(f"Created {len(chunks)} chunks")
# Out:
# Created 750 chunks

# %%
embed = embed_markdown(chunks, "openai")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 embed = embed_markdown(chunks, "openai")
#
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:309, in embed_markdown(chunks, provider_type, config)
#     307 config = config or EmbeddingConfig()
#     308 provider = get_provider(provider_type, config)
# --> 309 return embed_chunks(chunks, provider, config.batch_size)
#
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:261, in embed_chunks(chunks, provider, batch_size)
#     258     return []
#     260 texts = [chunk.content for chunk in chunks]
# --> 261 vectors = embed_texts(texts, provider, batch_size)
#     263 embeddings = []
#     264 for chunk, vector in zip(chunks, vectors):
#
# File ~/Documents/programing/rag_pipeline/vectordb/embeddings.py:215, in embed_texts(texts, provider, batch_size)
# ...

# %%
embed = embed_markdown(chunks)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
embed
# Out:
# [Embedding(vector=(-0.11583380401134491, -0.03220303729176521, 0.026402253657579422, -0.0033655264414846897, 0.00014878086221870035, -0.0687200203537941, -0.05453719571232796, -0.002844328060746193, -0.03005349449813366, 0.009140251204371452, -0.05116896331310272, 0.06787455826997757, -0.05889647826552391, 0.03493879735469818, 0.0865996852517128, 0.034159958362579346, 0.03607163205742836, 0.0223306305706501, -0.03869468346238136, -0.03763064742088318, 0.05284501239657402, -0.09812062978744507, -0.03138839080929756, -0.07394889742136002, 0.08780326694250107, 0.04654589667916298, 0.053603850305080414, 0.013727845624089241, 0.03938792645931244, -0.04965122416615486, 0.001221387181431055, -0.06482439488172531, -0.009334009140729904, 0.0016748481430113316, -0.10227655619382858, 0.0585789829492569, 0.0297444686293602, -0.056121401488780975, -0.05002254247665405, -0.004675885196775198, -0.10577425360679626, 0.019801899790763855, -0.02577875554561615, 0.02477353997528553, 0.00016669694741722
# ...

# %%
print(embed)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
print(chunks)
# Out:
# [Chunk(content='## Preface\nWeb development has been changing a lot in the last couple of years. JavaScript\nlibraries have matured, browsers have become more powerful, and the HTML5 spec\nis well supported on most systems. Currently, though, the Web mostly focuses on 2D\nto represent information, create games, and build websites. There is also, however, a\ngreat and standardized way to create 3D graphics. This is called WebGL; it provides\nan API to create hardware-accelerated 3D graphics.', source_file='/Users/anedu/Documents/programing/rag_pipeline/data/pdfs/clean.md', chunk_index=0, start_char=0, end_char=473, metadata={'frontmatter': {}, 'file_name': 'clean.md', 'chunk_size': 473, 'strategy': 'recursive'}), Chunk(content="However, the WebGL API isn't very easy to use. It requires you to program in C,\nand you really need to have an in-depth knowledge of how WebGL works\ninternally to work with this API. Luckily though, there are a number of JavaScript\nlibraries available that h
# ...

# %%
from vectordb import (
    chunk_markdown,
    embed_markdown,
    build_vector_store,
    query_vector_store,
    create_embed_function,
    VectorStoreConfig,
)

# %%
config = VectorStoreConfig(
        collection_name="my_documents",
    )

# %%
backend = build_vector_store(
        embed, backend_type="pgvector", config=config
    )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/programing/rag_pipeline/vectordb/vector_store.py:247, in create_pgvector_backend(config)
#     241 def create_pgvector_backend(config: VectorStoreConfig) -> VectorStoreBackend:
#     242     """
#     243     Create a PostgreSQL pgvector backend.
#     244
#     245     Requires:
#     246     - PostgreSQL with pgvector extension installed
# --> 247     - psycopg2 or psycopg package
#     248
#     249     Connection string format:
#     250         postgresql://user:password@host:port/database
#     251
#     252     Can be provided via:
#     253     - config.pg_connection_string (direct connection string)
#     254     - POSTGRES_CONNECTION_STRING env var
#     255     - Individual env vars: POSTGRES_USER, POSTGRES_PASSWORD, POSTGRES_HOST,
#     256       POSTGRES_PORT, POSTGRES_DB
#     257     """
# ...

# %%
backend = build_vector_store(
        embed, backend_type="pgvector", config=config
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 backend = build_vector_store(
#       2         embed, backend_type="pgvector", config=config
#       3     )
#
# File ~/Documents/programing/rag_pipeline/vectordb/vector_store.py:512, in build_vector_store(embeddings, backend_type, config)
#     502 for emb_id, score, metadata in results:
#     503     chunk = Chunk(
#     504         content=metadata.get("content", metadata.get("document", "")),
#     505         source_file=metadata.get("source_file", ""),
#    (...)    509         metadata={"file_name": metadata.get("file_name", "")},
#     510     )
#     511     search_results.append(
# --> 512         SearchResult(chunk=chunk, score=score, embedding_id=emb_id)
#     513     )
#     515 return search_results
#
# ...

# %%
pg_connection_string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pg_connection_string
#
# NameError: name 'pg_connection_string' is not defined

# %%
backend = build_vector_store(
        embed, backend_type="pgvector", config=config
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 backend = build_vector_store(
#       2         embed, backend_type="pgvector", config=config
#       3     )
#
# File ~/Documents/programing/rag_pipeline/vectordb/vector_store.py:512, in build_vector_store(embeddings, backend_type, config)
#     502 for emb_id, score, metadata in results:
#     503     chunk = Chunk(
#     504         content=metadata.get("content", metadata.get("document", "")),
#     505         source_file=metadata.get("source_file", ""),
#    (...)    509         metadata={"file_name": metadata.get("file_name", "")},
#     510     )
#     511     search_results.append(
# --> 512         SearchResult(chunk=chunk, score=score, embedding_id=emb_id)
#     513     )
#     515 return search_results
#
# ...

# %%
from vectordb import (
    chunk_markdown,
    embed_markdown,
    build_vector_store,
    query_vector_store,
    create_embed_function,
    VectorStoreConfig,
)

# %%
chunks = chunk_markdown("data/pdfs/clean.md")
print(f"Created {len(chunks)} chunks")
# Out:
# Created 750 chunks

# %%
embeddings = embed_markdown(chunks)

# %%
config = VectorStoreConfig(
        collection_name="my_documents",
    )

# %%
backend = build_vector_store(
        embed, backend_type="pgvector", config=config
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 backend = build_vector_store(
# ----> 2         embed, backend_type="pgvector", config=config
#       3     )
#
# NameError: name 'embed' is not defined

# %%
backend = build_vector_store(
        embedding, backend_type="pgvector", config=config
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 backend = build_vector_store(
# ----> 2         embedding, backend_type="pgvector", config=config
#       3     )
#
# NameError: name 'embedding' is not defined

# %%
backend = build_vector_store(
        embeddings, backend_type="pgvector", config=config
    )
